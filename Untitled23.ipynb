# %%
import pandas as pd

file = pd.read_csv('artworks.csv')
file
# Out:
#                                                    Title  \
# 0                         Dress MacLeod from Tartan Sets
# 1      Duplicate of plate from folio 11 verso (supple...
# 2                       Tailpiece (page 55) from SAGESSE
# 3      Headpiece (page 129) from LIVRET DE FOLASTRIES...
# 4                                          97 rue du Bac
# 5            Pictorial ornament (folio 11) from WOODCUTS
# 6                                Rue de l'Hôtel-de-Ville
# 7                                    Los Angeles Airport
# 8                       Why Defy from Disasters of Peace
# 9                                   STILL WATER AND FISH
# 10           In-text plate (folio 11) from LA MÉTROMANIE
# 11                                        Black Bathroom
# 12              In-text plate (page 108) from LYSISTRATA
# 13                 Transcendence. Designs for the Ballet
# 14                                              Untitled
# ...

# %%
df = pd.DataFrame(file)

# %%
df
# Out:
#                                                    Title  \
# 0                         Dress MacLeod from Tartan Sets
# 1      Duplicate of plate from folio 11 verso (supple...
# 2                       Tailpiece (page 55) from SAGESSE
# 3      Headpiece (page 129) from LIVRET DE FOLASTRIES...
# 4                                          97 rue du Bac
# 5            Pictorial ornament (folio 11) from WOODCUTS
# 6                                Rue de l'Hôtel-de-Ville
# 7                                    Los Angeles Airport
# 8                       Why Defy from Disasters of Peace
# 9                                   STILL WATER AND FISH
# 10           In-text plate (folio 11) from LA MÉTROMANIE
# 11                                        Black Bathroom
# 12              In-text plate (page 108) from LYSISTRATA
# 13                 Transcendence. Designs for the Ballet
# 14                                              Untitled
# ...

# %%
import csv
with open("artworks.csv") as f:
    artwork = csv.reader(f)

# %%
artwork

# %%
with open("artworks.csv") as f:
    contents_of_f = csv.reader(f)

# %%
contents_of_f

# %%
b = []
for c in contents_of_f:
    b = b.append(c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-cc6d398da3c6> in <module>
#       1 b = []
# ----> 2 for c in contents_of_f:
#       3     b = b.append(c)
#
# ValueError: I/O operation on closed file.

# %%
df.to_csv()
# Out:
# ',Title,Artist,Nationality,BeginDate,EndDate,Gender,Date,Department\r\n0,Dress MacLeod from Tartan Sets,Sarah Charlesworth,(American),(1947),(2013),(Female),1986,Prints & Illustrated Books\r\n1,"Duplicate of plate from folio 11 verso (supplementary suite, plate 4) from ARDICIA",Pablo Palazuelo,(Spanish),(1916),(2007),(Male),1978,Prints & Illustrated Books\r\n2,Tailpiece (page 55) from SAGESSE,Maurice Denis,(French),(1870),(1943),(Male),1889-1911,Prints & Illustrated Books\r\n3,"Headpiece (page 129) from LIVRET DE FOLASTRIES, À JANOT PARISIEN",Aristide Maillol,(French),(1861),(1944),(Male),1927-1940,Prints & Illustrated Books\r\n4,97 rue du Bac,Eugène Atget,(French),(1857),(1927),(Male),1903,Photography\r\n5,Pictorial ornament (folio 11) from WOODCUTS,Antonio Frasconi,(American),(1919),(2013),(Male),1957,Prints & Illustrated Books\r\n6,Rue de l\'Hôtel-de-Ville,Eugène Atget,(French),(1857),(1927),(Male),1924,Photography\r\n7,Los Angeles Airport,Garry Winogrand,(American),(1928),(1984),
# ...

# %%
nf = pd.DataFrame(file)

# %%
nf.to_csv()
# Out:
# ',Title,Artist,Nationality,BeginDate,EndDate,Gender,Date,Department\r\n0,Dress MacLeod from Tartan Sets,Sarah Charlesworth,(American),(1947),(2013),(Female),1986,Prints & Illustrated Books\r\n1,"Duplicate of plate from folio 11 verso (supplementary suite, plate 4) from ARDICIA",Pablo Palazuelo,(Spanish),(1916),(2007),(Male),1978,Prints & Illustrated Books\r\n2,Tailpiece (page 55) from SAGESSE,Maurice Denis,(French),(1870),(1943),(Male),1889-1911,Prints & Illustrated Books\r\n3,"Headpiece (page 129) from LIVRET DE FOLASTRIES, À JANOT PARISIEN",Aristide Maillol,(French),(1861),(1944),(Male),1927-1940,Prints & Illustrated Books\r\n4,97 rue du Bac,Eugène Atget,(French),(1857),(1927),(Male),1903,Photography\r\n5,Pictorial ornament (folio 11) from WOODCUTS,Antonio Frasconi,(American),(1919),(2013),(Male),1957,Prints & Illustrated Books\r\n6,Rue de l\'Hôtel-de-Ville,Eugène Atget,(French),(1857),(1927),(Male),1924,Photography\r\n7,Los Angeles Airport,Garry Winogrand,(American),(1928),(1984),
# ...

# %%
import tkinter
