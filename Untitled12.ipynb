# %%
import numpy as np
import pandas as pd

# %%
data = pd.Series(np.random.randn(9),index=[['a', 'a', 'a', 'b', 'b', 'c', 'c', 'd', 'd'],[1, 2, 3, 1, 3, 1, 2, 2, 3]])

# %%
data
# Out:
# a  1   -0.624810
#    2    0.854724
#    3   -0.826975
# b  1    0.226886
#    3    0.060373
# c  1    1.667255
#    2    1.282125
# d  2   -0.290090
#    3   -1.000996
# dtype: float64

# %%
data.index
# Out:
# MultiIndex(levels=[['a', 'b', 'c', 'd'], [1, 2, 3]],
#            codes=[[0, 0, 0, 1, 1, 2, 2, 3, 3], [0, 1, 2, 0, 2, 0, 1, 1, 2]])

# %%
data[['a' , 'c']]
# Out:
# a  1   -0.624810
#    2    0.854724
#    3   -0.826975
# c  1    1.667255
#    2    1.282125
# dtype: float64

# %%
data['a' : 'c']
# Out:
# a  1   -0.624810
#    2    0.854724
#    3   -0.826975
# b  1    0.226886
#    3    0.060373
# c  1    1.667255
#    2    1.282125
# dtype: float64

# %%
data.unstack()
# Out:
#           1         2         3
# a -0.624810  0.854724 -0.826975
# b  0.226886       NaN  0.060373
# c  1.667255  1.282125       NaN
# d       NaN -0.290090 -1.000996

# %%
data1 = data.unstack()

# %%
data1.stack()
# Out:
# a  1   -0.624810
#    2    0.854724
#    3   -0.826975
# b  1    0.226886
#    3    0.060373
# c  1    1.667255
#    2    1.282125
# d  2   -0.290090
#    3   -1.000996
# dtype: float64

# %%
frame = pd.DataFrame(np.arange(12).reshape((4, 3)),index=[['a', 'a', 'b', 'b'], [1, 2, 1, 2]],columns=[['Ohio', 'Ohio', 'Colorado'],['Green', 'Red', 'Green']])

# %%
frame
# Out:
#      Ohio     Colorado
#     Green Red    Green
# a 1     0   1        2
#   2     3   4        5
# b 1     6   7        8
#   2     9  10       11

# %%
frame.index.names = ['key1', 'key2']

# %%
frame
# Out:
#            Ohio     Colorado
#           Green Red    Green
# key1 key2
# a    1        0   1        2
#      2        3   4        5
# b    1        6   7        8
#      2        9  10       11

# %%
frame.columns.names = ['state', 'color']

# %%
frame
# Out:
# state      Ohio     Colorado
# color     Green Red    Green
# key1 key2
# a    1        0   1        2
#      2        3   4        5
# b    1        6   7        8
#      2        9  10       11

# %%
frame['Ohio']
# Out:
# color      Green  Red
# key1 key2
# a    1         0    1
#      2         3    4
# b    1         6    7
#      2         9   10

# %%
frame.swaplevel('key1', 'key2')
# Out:
# state      Ohio     Colorado
# color     Green Red    Green
# key2 key1
# 1    a        0   1        2
# 2    a        3   4        5
# 1    b        6   7        8
# 2    b        9  10       11

# %%
frame.sort_index(level=1)
# Out:
# state      Ohio     Colorado
# color     Green Red    Green
# key1 key2
# a    1        0   1        2
# b    1        6   7        8
# a    2        3   4        5
# b    2        9  10       11

# %%
mobData = pd.read_csv('20190928-items.csv')

# %%
mobData
# Out:
#            asin     brand                                              title  \
# 0    B0000SX2UC     Nokia  Dual-Band / Tri-Mode Sprint PCS Phone w/ Voice...
# 1    B0009N5L7K  Motorola                                Motorola I265 phone
# 2    B000SKTZ0S  Motorola  MOTOROLA C168i AT&T CINGULAR PREPAID GOPHONE C...
# 3    B00198M12M     Nokia  Nokia 6500 Slide Black/silver Unlocked Cell Phone
# 4    B001AO4OUC  Motorola              Motorola i335 Cell Phone Boost Mobile
# 5    B001DCJAJG  Motorola      Motorola V365 no contract cellular phone AT&T
# 6    B001DZY4KI      Sony  Sony Ericsson G700 Triband GSM Phone Bronze (U...
# 7    B001GQ3DJM     Nokia                  Nokia 1680 Black Phone (T-Mobile)
# 8    B0027VKQPE     Nokia                        Nokia New 1100 for Tracfone
# 9    B00280QJFU   Samsung             Samsung T301G Prepaid Phone (Tracfone)
# 10   B0029X7UHC  Motorola              Motorola I205 cell phone nextel/Boost
# ...

# %%
student = pd.read_csv("Name.csv")

# %%
std_con = pd.read_csv('contact.csv')

# %%
student
std_con
# Out:
#    Roll No    Con
# 0       11   8899
# 1     3424  32423
# 2       12   9247
# 3       13   8279

# %%
pd.merge(student,std_con, on = 'Roll No')
# Out:
#      Name Class  Roll No   Con
# 0   Baqar    AI       11  8899
# 1  Masood    AI       12  9247
# 2  Kamran    AI       13  8279

# %%
pd.merge(student,std_con, left_on = 'Roll No')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-e946a5d119f3> in <module>
# ----> 1 pd.merge(student,std_con, left_on = 'Roll No')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      45                          right_index=right_index, sort=sort, suffixes=suffixes,
#      46                          copy=copy, indicator=indicator,
# ---> 47                          validate=validate)
#      48     return op.get_result()
#      49
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     522             warnings.warn(msg, UserWarning)
#     523
# ...

# %%
student.join(std_con, how = 'inner')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-1b58278befe2> in <module>
# ----> 1 student.join(std_con, how = 'inner')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    6813         # For SparseDataFrame's benefit
#    6814         return self._join_compat(other, on=on, how=how, lsuffix=lsuffix,
# -> 6815                                  rsuffix=rsuffix, sort=sort)
#    6816
#    6817     def _join_compat(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    6828             return merge(self, other, left_on=on, how=how,
#    6829                          left_index=on is None, right_index=True,
# ...

# %%
ufc = pd.read_csv("data.csv")

# %%
ufc.head()
# Out:
#               R_fighter       B_fighter          Referee        date  \
# 0          Henry Cejudo   Marlon Moraes     Marc Goddard  2019-06-08
# 1  Valentina Shevchenko     Jessica Eye  Robert Madrigal  2019-06-08
# 2         Tony Ferguson  Donald Cerrone  Dan Miragliotta  2019-06-08
# 3         Jimmie Rivera        Petr Yan  Kevin MacDonald  2019-06-08
# 4           Tai Tuivasa   Blagoy Ivanov  Dan Miragliotta  2019-06-08
#
#                  location Winner  title_bout       weight_class  no_of_rounds  \
# 0  Chicago, Illinois, USA    Red        True       Bantamweight             5
# 1  Chicago, Illinois, USA    Red        True  Women's Flyweight             5
# 2  Chicago, Illinois, USA    Red       False        Lightweight             3
# 3  Chicago, Illinois, USA   Blue       False       Bantamweight             3
# 4  Chicago, Illinois, USA   Blue       False        Heavyweight             3
#
#    B_current_lose_streak  ...  R_win_by_KO/TKO  R_win_by_Submission  \
# ...

# %%
ufc.describe()
# Out:
#        no_of_rounds  B_current_lose_streak  B_current_win_streak  B_draw  \
# count   5144.000000            5144.000000           5144.000000  5144.0
# mean       3.119362               0.429821              0.837286     0.0
# std        0.631457               0.731325              1.306203     0.0
# min        1.000000               0.000000              0.000000     0.0
# 25%        3.000000               0.000000              0.000000     0.0
# 50%        3.000000               0.000000              0.000000     0.0
# 75%        3.000000               1.000000              1.000000     0.0
# max        5.000000               6.000000             13.000000     0.0
#
#        B_avg_BODY_att  B_avg_BODY_landed  B_avg_CLINCH_att  \
# count     3879.000000        3879.000000       3879.000000
# mean         8.689387           6.083457          8.240461
# std          7.087703           5.074464          7.575422
# min          0.000000           0.000000          0.000000
# ...

# %%
ufc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5144 entries, 0 to 5143
# Columns: 145 entries, R_fighter to R_age
# dtypes: bool(1), float64(134), int64(1), object(9)
# memory usage: 5.7+ MB

# %%
ufc.select_dtypes(include = ['float64'])
# Out:
#       B_current_lose_streak  B_current_win_streak  B_draw  B_avg_BODY_att  \
# 0                       0.0                   4.0     0.0        9.200000
# 1                       0.0                   3.0     0.0       14.600000
# 2                       0.0                   3.0     0.0       15.354839
# 3                       0.0                   4.0     0.0       17.000000
# 4                       0.0                   1.0     0.0       17.000000
# 5                       0.0                   4.0     0.0       19.500000
# 6                       0.0                   3.0     0.0       15.000000
# 7                       1.0                   0.0     0.0       16.250000
# 8                       0.0                   1.0     0.0        7.250000
# 9                       0.0                   1.0     0.0       25.400000
# 10                      1.0                   0.0     0.0        5.428571
# 11                      0.0                   0.0     0.0             NaN
# ...

# %%
fighters = pd.concat([ufc['R_fighter'], ufc['B_fighter']], ignore_index=True)

# %%
fighters
# Out:
# 0                 Henry Cejudo
# 1         Valentina Shevchenko
# 2                Tony Ferguson
# 3                Jimmie Rivera
# 4                  Tai Tuivasa
# 5               Tatiana Suarez
# 6            Aljamain Sterling
# 7        Karolina Kowalkiewicz
# 8                Ricardo Lamas
# 9                  Yan Xiaonan
# 10                 Bevon Lewis
# 11              Eddie Wineland
# 12           Katlyn Chookagian
# 13        Alexander Gustafsson
# 14                 Jimi Manuwa
# 15            Makwan Amirkhani
# 16              Damir Hadzovic
# 17               Daniel Teymur
# 18                Rostem Akman
# 19               Tonya Evinger
# 20                  Stevie Ray
# 21                   Nick Hein
# 22                 Bea Malecki
# 23                Darko Stosic
# 24                Joel Alvarez
# 25            Rafael Dos Anjos
# 26       Antonio Carlos Junior
# 27              Megan Anderson
# 28               Vicente Luque
# 29            Charles Oliveira
# ...

# %%
fighters1 = pd.concat([ufc['R_fighter'], ufc['B_fighter']])
fighters1
# Out:
# 0                Henry Cejudo
# 1        Valentina Shevchenko
# 2               Tony Ferguson
# 3               Jimmie Rivera
# 4                 Tai Tuivasa
# 5              Tatiana Suarez
# 6           Aljamain Sterling
# 7       Karolina Kowalkiewicz
# 8               Ricardo Lamas
# 9                 Yan Xiaonan
# 10                Bevon Lewis
# 11             Eddie Wineland
# 12          Katlyn Chookagian
# 13       Alexander Gustafsson
# 14                Jimi Manuwa
# 15           Makwan Amirkhani
# 16             Damir Hadzovic
# 17              Daniel Teymur
# 18               Rostem Akman
# 19              Tonya Evinger
# 20                 Stevie Ray
# 21                  Nick Hein
# 22                Bea Malecki
# 23               Darko Stosic
# 24               Joel Alvarez
# 25           Rafael Dos Anjos
# 26      Antonio Carlos Junior
# 27             Megan Anderson
# 28              Vicente Luque
# 29           Charles Oliveira
#                 ...
# ...

# %%
fighters.unique()
# Out:
# array(['Henry Cejudo', 'Valentina Shevchenko', 'Tony Ferguson', ...,
#        'Trent Jenkins', 'Art Jimmerson', 'Teila Tuli'], dtype=object)

# %%
len(fighters.unique())
# Out:
# 1915

# %%
ufc['weight_class'].value_counts().plot(kind='bar')

# %%
ufc['no_of_rounds'].value_counts().plot(kind='bar')

# %%
ufc['Winner'].value_counts().plot(kind='bar')

# %%
red_winner = ufc['Winner'] == "Red"
blue_winner = ufc['Winner'] == "Blue"
Draw = ufc['Winner'] == "Draw"
red_winner.sum()
# Out:
# 3470

# %%
blue_winner.sum()
# Out:
# 1591

# %%
Draw.sum()
# Out:
# 83

# %%
rou = ufc["no_of_rounds"] == 3

# %%
rou.sum()
# Out:
# 4523

# %%
red_winner = ufc[ufc['Winner'] == "Red"]
red_winner['no_of_rounds'].value_counts().plot(kind='bar')

# %%
Red_Winner.sum()
# Out:
# R_fighter                       Henry CejudoValentina ShevchenkoTony FergusonT...
# B_fighter                       Marlon MoraesJessica EyeDonald CerroneNina Ans...
# date                            2019-06-082019-06-082019-06-082019-06-082019-0...
# location                        Chicago, Illinois, USAChicago, Illinois, USACh...
# Winner                          RedRedRedRedRedRedRedRedRedRedRedRedRedRedRedR...
# title_bout                                                                    269
# weight_class                    BantamweightWomen's FlyweightLightweightWomen'...
# no_of_rounds                                                                10764
# B_current_lose_streak                                                        1467
# B_current_win_streak                                                         2741
# B_draw                                                                          0
# ...

# %%
ufc['country'] = ufc['location'].apply(lambda x: x.split(',')[-1])

# %%
ufc["country"]
# Out:
# 0           USA
# 1           USA
# 2           USA
# 3           USA
# 4           USA
# 5           USA
# 6           USA
# 7           USA
# 8           USA
# 9           USA
# 10          USA
# 11          USA
# 12          USA
# 13       Sweden
# 14       Sweden
# 15       Sweden
# 16       Sweden
# 17       Sweden
# 18       Sweden
# 19       Sweden
# 20       Sweden
# 21       Sweden
# 22       Sweden
# 23       Sweden
# 24       Sweden
# 25          USA
# 26          USA
# 27          USA
# 28          USA
# 29          USA
#          ...
# 5114        USA
# 5115        USA
# 5116        USA
# 5117        USA
# 5118        USA
# 5119        USA
# 5120        USA
# 5121        USA
# 5122        USA
# 5123        USA
# 5124        USA
# 5125        USA
# 5126        USA
# 5127        USA
# 5128        USA
# 5129        USA
# 5130        USA
# 5131        USA
# 5132        USA
# 5133        USA
# 5134        USA
# 5135        USA
# 5136        USA
# 5137        USA
# ...

# %%
ufc["country"].value_counts().plot(kind="bar")

# %%
ufc["year"] = ufc['date'].apply(lambda x: x.split('-')[0])

# %%
ufc['year']
# Out:
# 0       2019
# 1       2019
# 2       2019
# 3       2019
# 4       2019
# 5       2019
# 6       2019
# 7       2019
# 8       2019
# 9       2019
# 10      2019
# 11      2019
# 12      2019
# 13      2019
# 14      2019
# 15      2019
# 16      2019
# 17      2019
# 18      2019
# 19      2019
# 20      2019
# 21      2019
# 22      2019
# 23      2019
# 24      2019
# 25      2019
# 26      2019
# 27      2019
# 28      2019
# 29      2019
#         ...
# 5114    1994
# 5115    1994
# 5116    1994
# 5117    1994
# 5118    1994
# 5119    1994
# 5120    1994
# 5121    1994
# 5122    1994
# 5123    1994
# 5124    1994
# 5125    1994
# 5126    1994
# 5127    1994
# 5128    1994
# 5129    1994
# 5130    1994
# 5131    1994
# 5132    1994
# 5133    1994
# 5134    1994
# 5135    1994
# 5136    1993
# 5137    1993
# 5138    1993
# 5139    1993
# 5140    1993
# 5141    1993
# 5142    1993
# 5143    1993
# Name: year, Length: 5144, dtype: object

# %%
ufc['year'].value_counts().plot(kind="bar")

# %%
ufc["month"] = ufc['date'].apply(lambda x: x.split('-')[1])

# %%
ufc['month']
# Out:
# 0       06
# 1       06
# 2       06
# 3       06
# 4       06
# 5       06
# 6       06
# 7       06
# 8       06
# 9       06
# 10      06
# 11      06
# 12      06
# 13      06
# 14      06
# 15      06
# 16      06
# 17      06
# 18      06
# 19      06
# 20      06
# 21      06
# 22      06
# 23      06
# 24      06
# 25      05
# 26      05
# 27      05
# 28      05
# 29      05
#         ..
# 5114    12
# 5115    09
# 5116    09
# 5117    09
# 5118    09
# 5119    09
# 5120    09
# 5121    03
# 5122    03
# 5123    03
# 5124    03
# 5125    03
# 5126    03
# 5127    03
# 5128    03
# 5129    03
# 5130    03
# 5131    03
# 5132    03
# 5133    03
# 5134    03
# 5135    03
# 5136    11
# 5137    11
# 5138    11
# 5139    11
# 5140    11
# 5141    11
# 5142    11
# 5143    11
# Name: month, Length: 5144, dtype: object

# %%
ufc['month'].value_counts().plot(kind='bar')
