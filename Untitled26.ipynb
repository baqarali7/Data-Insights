# %%
import numpy
import pandas
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
# Out:
# Using TensorFlow backend.

# %%
seed = 7
numpy.random.seed(seed)

# %%
dataframe = pandas.read_csv("FarmingDataset.csv", header=None)
dataset = dataframe.values

# %%
dataset
# Out:
# array([[0.7, 0.6, 0.8, ..., 0.9, 4. , 1. ],
#        [0.5, 0.5, 0.4, ..., 0.8, 2. , 1. ],
#        [0.6, 0.8, 0.1, ..., 0.6, 2. , 1. ],
#        ...,
#        [0.7, 0.8, 0.3, ..., 0.7, 2. , 0. ],
#        [0.6, 0.5, 0.8, ..., 0.7, 4. , 1. ],
#        [0.4, 0.4, 0.8, ..., 0.8, 1. , 0. ]])

# %%
X = dataset[:,0:10].astype(float)
Y = dataset[:,10]

# %%
X
# Out:
# array([[0.7, 0.6, 0.8, ..., 0.1, 0.9, 4. ],
#        [0.5, 0.5, 0.4, ..., 0.7, 0.8, 2. ],
#        [0.6, 0.8, 0.1, ..., 0.6, 0.6, 2. ],
#        ...,
#        [0.7, 0.8, 0.3, ..., 0.5, 0.7, 2. ],
#        [0.6, 0.5, 0.8, ..., 0.3, 0.7, 4. ],
#        [0.4, 0.4, 0.8, ..., 0.7, 0.8, 1. ]])

# %%
Y
# Out:
# array([1., 1., 1., ..., 0., 1., 0.])

# %%
def create_baseline():
    model = Sequential()
    model.add(Dense(10, activation='relu', input_shape=(X.shape[1],)))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
estimator = KerasClassifier(build_fn=create_baseline, epochs=150, batch_size=5, verbose=0)
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=seed)
results = cross_val_score(estimator, X, Y, cv=kfold)
print("Results: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# Results: 79.55% (1.52%)

# %%
scaler = StandardScaler()

# %%
print(scaler.fit(X))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
normalize_X = scaler.transform(X)

# %%
numpy.random.seed(seed)
estimators = []
estimators.append(('standardize', StandardScaler()))
estimators.append(('mlp', KerasClassifier(build_fn=create_baseline, epochs=100, batch_size=5, verbose=1)))
pipeline = Pipeline(estimators)
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=seed)
results = cross_val_score(pipeline, normalize_X, Y, cv=kfold)
print("Standardized: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# Epoch 1/100
# 1438/1438 [==============================] - 1s 430us/step - loss: 0.4605 - accuracy: 0.7559
# Epoch 2/100
# 1438/1438 [==============================] - 0s 324us/step - loss: 0.3718 - accuracy: 0.7990
# Epoch 3/100
# 1438/1438 [==============================] - 0s 319us/step - loss: 0.3607 - accuracy: 0.7949
# Epoch 4/100
# 1438/1438 [==============================] - 0s 318us/step - loss: 0.3551 - accuracy: 0.8060
# Epoch 5/100
# 1438/1438 [==============================] - 0s 329us/step - loss: 0.3506 - accuracy: 0.8060
# Epoch 6/100
# 1438/1438 [==============================] - 0s 334us/step - loss: 0.3481 - accuracy: 0.8143
# Epoch 7/100
# 1438/1438 [==============================] - 0s 337us/step - loss: 0.3459 - accuracy: 0.8136
# Epoch 8/100
# 1438/1438 [==============================] - 0s 334us/step - loss: 0.3443 - accuracy: 0.8136
# Epoch 9/100
# 1438/1438 [==============================] - 0s 345us/step - loss: 0.3423 - accuracy: 0.8206
# Epoch 10/100
# ...

# %%
def create_smaller():
    model = Sequential()
    model.add(Dense(5, activation='relu', input_shape=(X.shape[1],)))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
numpy.random.seed(seed)
estimators = []
estimators.append(('standardize', StandardScaler()))
estimators.append(('mlp', KerasClassifier(build_fn=create_smaller, epochs=100, batch_size=5, verbose=1)))
pipeline = Pipeline(estimators)
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=seed)
results = cross_val_score(pipeline, normalize_X, Y, cv=kfold)
print("Standardized: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# Epoch 1/100
# 1438/1438 [==============================] - 1s 425us/step - loss: 0.6457 - accuracy: 0.6474
# Epoch 2/100
# 1438/1438 [==============================] - 0s 326us/step - loss: 0.4697 - accuracy: 0.8067
# Epoch 3/100
# 1438/1438 [==============================] - 0s 316us/step - loss: 0.4051 - accuracy: 0.8025
# Epoch 4/100
# 1438/1438 [==============================] - 0s 321us/step - loss: 0.3840 - accuracy: 0.7990
# Epoch 5/100
# 1438/1438 [==============================] - 0s 312us/step - loss: 0.3744 - accuracy: 0.8004
# Epoch 6/100
# 1438/1438 [==============================] - 1s 351us/step - loss: 0.3694 - accuracy: 0.8004
# Epoch 7/100
# 1438/1438 [==============================] - 1s 386us/step - loss: 0.3658 - accuracy: 0.7955
# Epoch 8/100
# 1438/1438 [==============================] - 0s 327us/step - loss: 0.3635 - accuracy: 0.7969
# Epoch 9/100
# 1438/1438 [==============================] - 0s 303us/step - loss: 0.3608 - accuracy: 0.7955
# Epoch 10/100
# ...

# %%
def create_larger():
    model = Sequential()
    model.add(Dense(10, activation='relu', input_shape=(X.shape[1],)))
    model.add(Dense(7, activation='relu', input_shape=(X.shape[1],)))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
numpy.random.seed(seed)
estimators = []
estimators.append(('standardize', StandardScaler()))
estimators.append(('mlp', KerasClassifier(build_fn=create_larger, epochs=100, batch_size=5, verbose=0)))
pipeline = Pipeline(estimators)
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=seed)
results = cross_val_score(pipeline, normalize_X, Y, cv=kfold)
print("Standardized: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# Standardized: 76.79% (2.75%)

# %%
def create_larger2():
    model = Sequential()
    model.add(Dense(10, activation='relu', input_shape=(X.shape[1],)))
    model.add(Dense(7, activation='relu', input_shape=(X.shape[1],)))
    model.add(Dense(5, activation='relu', input_shape=(X.shape[1],)))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
numpy.random.seed(seed)
estimators = []
estimators.append(('standardize', StandardScaler()))
estimators.append(('mlp', KerasClassifier(build_fn=create_larger2, epochs=100, batch_size=5, verbose=1)))
pipeline = Pipeline(estimators)
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=seed)
results = cross_val_score(pipeline, normalize_X, Y, cv=kfold)
print("Standardized: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# Epoch 1/100
# 1438/1438 [==============================] - 1s 428us/step - loss: 0.5849 - accuracy: 0.6954
# Epoch 2/100
# 1438/1438 [==============================] - 0s 328us/step - loss: 0.3851 - accuracy: 0.7775
# Epoch 3/100
# 1438/1438 [==============================] - 0s 321us/step - loss: 0.3639 - accuracy: 0.7914
# Epoch 4/100
# 1438/1438 [==============================] - 0s 312us/step - loss: 0.3575 - accuracy: 0.8032
# Epoch 5/100
# 1438/1438 [==============================] - 0s 330us/step - loss: 0.3552 - accuracy: 0.8053
# Epoch 6/100
# 1438/1438 [==============================] - 0s 315us/step - loss: 0.3537 - accuracy: 0.8053
# Epoch 7/100
# 1438/1438 [==============================] - 0s 322us/step - loss: 0.3523 - accuracy: 0.8115
# Epoch 8/100
# 1438/1438 [==============================] - 0s 313us/step - loss: 0.3509 - accuracy: 0.8136
# Epoch 9/100
# 1438/1438 [==============================] - 0s 320us/step - loss: 0.3496 - accuracy: 0.8171
# Epoch 10/100
# ...
